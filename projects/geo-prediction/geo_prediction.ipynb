# %%
# Clone the repo
# !git clone https://github.com/atikul-islam-sajib/Other-Tasks.git

# %%
# Change the directory
# %cd geo-prediction

# %%
# !pip install -r requirements.txt

# %%
# !pip install factor-analyzer
# Out:
# Collecting factor-analyzer
#   Downloading factor_analyzer-0.5.1.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 826.9 kB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from factor-analyzer) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from factor-analyzer) (1.11.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from factor-analyzer) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from factor-analyzer) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->factor-analyzer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->factor-analyzer) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->factor-analyzer) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->factor-analyzer) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->factor-analyzer) (1.16.0)
# Building wheels for collected packages: factor-analyzer
#   Building wheel for factor-analyzer (pyproject.toml) ... done
#   Created wheel for factor-analyzer: filename=factor_analyzer-0.5.1-py2.py3-none-any.whl size=42564 sha256=bcf5d2df7bd038414b412eefadc99409d580f9f68d9d552e49a946902a0f6e2b
#   Stored in directory: /root/.cache/pip/wheels/24/59/82/6493618e30ed1cb7a013b9e1b0c9e17de80b04dfcef4ba8a4d
# Successfully built factor-analyzer
# Installing collected packages: factor-analyzer
# Successfully installed factor-analyzer-0.5.1

# %%
Confusion Matrix:
 [[ 77  10 122  25  51]
 [  0   2   0   1   0]
 [  7   0  27   0   1]
 [  0   0   0   8   2]
 [  7   0   0   0  15]]

Classification Report:
               precision    recall  f1-score   support

           0       0.85      0.27      0.41       285
           1       0.17      0.67      0.27         3
           2       0.18      0.77      0.29        35
           3       0.24      0.80      0.36        10
           4       0.22      0.68      0.33        22

    accuracy                           0.36       355
   macro avg       0.33      0.64      0.33       355
weighted avg       0.72      0.36      0.39       355

# %%
# Run the main.py
# %run /content/main.py
# Out:
# Current working directory
# /content
#  ====> Duration 0.01 secs:
#     Moves the last n columns of the DataFrame to the front.
#
#     Parameters:
#     df (pd.DataFrame): The DataFrame to reorder.
#     n (int): The number of columns from the end to move to the front.
#
#     Returns:
#     pd.DataFrame: The reordered DataFrame.
#
# Eigenvalues > 1:  4 1. Eigenvalue /float_div 10.00:  4
# Number of features in configuration:  5
# min(Number Eigenvalues (ev) > 1, Number Ev > (1.Ev/10)):  4
# (232, 4)
#  ====> Duration 0.65 secs: Faktor analyzer with PCA & VARIMAX-rotation matrix
#  ====> Duration 0.03 secs: BIRCH-Clustering Algorithm
#  ====> Duration 0.01 secs: Gets onehoted & summarized households for each cluster
#
#
# Confusion Matrix:
#  [[ 77  10 122  25  51]
#  [  0   2   0   1   0]
#  [  7   0  27   0   1]
#  [  0   0   0   8   2]
#  [  7   0   0   0  15]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.27      0.41       285
#            1       0.17      0.67      0.27         3
#            2       0.18      0.77      0.29        35
#            3       0.24      0.80      0.36        10
#            4       0.22      0.68      0.33        22
#
#     accuracy                           0.36       355
#    macro avg       0.33      0.64      0.33       355
# weighted avg       0.72      0.36      0.39       355
#
# Cluster_1
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.02 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.02 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.03 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.03 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.01 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.02 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
# ...
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.02 secs: Defines the cosine similarity function
#  ====> Duration 0.01 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.03 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.00 secs: Defines the cosine similarity function
#  ====> Duration 0.10 secs: Gets onehoted & summarized households for each cluster
#  ====> Duration 0.01 secs: counts cells where similarity is '>70%', '>75%', '>80%', '>85%', '>90%', '>95%'
#  ====> Duration 0.01 secs: counts cells where similarity is '>70%', '>75%', '>80%', '>85%', '>90%', '>95%'
#  ====> Duration 0.01 secs: counts cells where similarity is '>70%', '>75%', '>80%', '>85%', '>90%', '>95%'
#  ====> Duration 0.01 secs: counts cells where similarity is '>70%', '>75%', '>80%', '>85%', '>90%', '>95%'
#  ====> Duration 18.18 secs: Main: Geo-Prediction of new customers' based on calculated geo-segments
